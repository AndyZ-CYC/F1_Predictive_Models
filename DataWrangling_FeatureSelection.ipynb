# %%
import pandas as pd
import numpy as np
import os

# %%
file_path = './data/f1_data_2018_2023.csv'
data_df = pd.read_csv(file_path)

# %%
data_df.head(10)
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 0             5      S VETTEL          VET          vettel          Ferrari
# 1            44    L HAMILTON          HAM        hamilton         Mercedes
# 2             7   K RAIKKONEN          RAI       raikkonen          Ferrari
# 3             3   D RICCIARDO          RIC       ricciardo  Red Bull Racing
# 4            14      F ALONSO          ALO          alonso          McLaren
# 5            33  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 6            27  N HULKENBERG          HUL      hulkenberg          Renault
# 7            77      V BOTTAS          BOT          bottas         Mercedes
# 8             2   S VANDOORNE          VAN       vandoorne          McLaren
# 9            55       C SAINZ          SAI           sainz          Renault
#
#   TeamColor    TeamId  FirstName    LastName           FullName  ...  \
# ...

# %%
data_df.columns
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position_Race', 'ClassifiedPosition',
#        'GridPosition', 'Q1_Race', 'Q2_Race', 'Q3_Race', 'Time', 'Status',
#        'Points', 'RaceDate', 'TotalLaps', 'LapLength', 'Position_Qual',
#        'Q1_Qual', 'Q2_Qual', 'Q3_Qual', 'AirTemp', 'Humidity', 'Pressure',
#        'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'Year',
#        'RaceName'],
#       dtype='object')

# %%
data_df.shape
# Out:
# (2617, 37)

# %%
data_df.isnull().sum()
# Out:
# DriverNumber             0
# BroadcastName            0
# Abbreviation             0
# DriverId              1237
# TeamName                 0
# TeamColor                0
# TeamId                1237
# FirstName                0
# LastName                 0
# FullName                 0
# HeadshotUrl            605
# CountryCode           1679
# Position_Race         1237
# ClassifiedPosition    1237
# GridPosition          1237
# Q1_Race               2617
# Q2_Race               2617
# Q3_Race               2617
# Time                  1945
# Status                1237
# Points                1237
# RaceDate                 0
# TotalLaps                0
# LapLength                0
# Position_Qual            5
# Q1_Qual                 38
# Q2_Qual                699
# Q3_Qual               1344
# AirTemp                  0
# Humidity                 0
# Pressure                 0
# Rainfall                 0
# TrackTemp                0
# WindDirection            0
# ...
